# %%
import sys
sys.path.append("C:\\Users\\yaloz\\Documents\\GitKraken\\SIF_Reader\\sifreader")

import numpy
import matplotlib.pyplot as plt
import matplotlib
import xarray as xr
from sifreader import SIFFile

# %%
file = SIFFile('z 147.sif')
print(file)
# Out:
# ...
# Original Filename:             C:\Documents and Settings\Administrator\Desktop\report\defocus\z 147.sif
# Date:                          Tue Feb  4 19:02:50 2020
# Camera Model:                  Luc285_MONO
# Temperature (deg.C):           -20.000000
# Exposure Time:                 1.000000
# Cycle Time:                    0.000000
# Number of accumulations:       1
# Pixel Readout Rate (MHz):      12.500000
# Horizontal Camera Resolution:  1004
# Vertical Camera Resolution:    1002
# Image width:                   1004
# Image Height:                  1002
# Horizontal Binning:            1
# Vertical Binning:              1
# EM Gain level:                 100.000000
# Vertical Shift Speed:          0.000001
# Pre-Amplifier Gain:            1.000000
# Stacksize:                     1
# Filesize:                      8053388
# Offset to Image Data:          4029348.000000

# %%
xarr = file.as_xarray()
xarr.plot()

# %%
intensity = file.read_block(0)
for i in 
print(intensity[1000, 800])
intensity_plot = plt.imshow(intensity)
# Out:
# 501.0

# %%
SIFFile
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-601e56451eaa> in <module>
#       1 x_axis = file.x_axis
# ----> 2 y_axis = file.y_axis
#       3 intensity = file.intensity
#
# AttributeError: 'SIFFile' object has no attribute 'y_axis'
